# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import random
from matplotlib import image as img

# %%
# Loading the training and testing data into data frames

training_set = pd.read_csv("Human Action Recognition\Training_set.csv")
testing_set = pd.read_csv("Human Action Recognition\Testing_set.csv")

# %%
training_set
# Out:
#               filename               label
# 0          Image_1.jpg             sitting
# 1          Image_2.jpg        using_laptop
# 2          Image_3.jpg             hugging
# 3          Image_4.jpg            sleeping
# 4          Image_5.jpg        using_laptop
# ...                ...                 ...
# 12595  Image_12596.jpg             sitting
# 12596  Image_12597.jpg            clapping
# 12597  Image_12598.jpg             sitting
# 12598  Image_12599.jpg             dancing
# 12599  Image_12600.jpg  listening_to_music
#
# [12600 rows x 2 columns]

# %%
training_set.dtypes
# Out:
# filename    object
# label       object
# dtype: object

# %%
training_set.isnull().sum()
# Out:
# filename    0
# label       0
# dtype: int64

# %%
testing_set
# Out:
#             filename
# 0        Image_1.jpg
# 1        Image_2.jpg
# 2        Image_3.jpg
# 3        Image_4.jpg
# 4        Image_5.jpg
# ...              ...
# 5395  Image_5396.jpg
# 5396  Image_5397.jpg
# 5397  Image_5398.jpg
# 5398  Image_5399.jpg
# 5399  Image_5400.jpg
#
# [5400 rows x 1 columns]

# %% [markdown]
# ### There are 12 600 images in the training set and 5400 images in the testing set.

# %%
# Plotting the data distribution across the 15 classes in the training set

plt.figure(figsize=(20,10))
sns.countplot(training_set.label)
# Out:
# c:\Users\steph\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
counts = training_set['label'].value_counts()
print(counts)
# Out:
# sitting               840
# using_laptop          840
# hugging               840
# sleeping              840
# drinking              840
# clapping              840
# dancing               840
# cycling               840
# calling               840
# laughing              840
# eating                840
# fighting              840
# listening_to_music    840
# running               840
# texting               840
# Name: label, dtype: int64

# %% [markdown]
# ### There are 840 labelled images in each class in the training set.

# %%
# Loading the training set images into an array
# Decided to load the images in as 150 x 150 pixels arbitrarily

img_data = []
img_label = []

for i in range(len(training_set)):
    img = "Human Action Recognition/train/" + training_set["filename"][i]
    img = load_img(img, target_size=(150, 150))
    img = img_to_array(img)
    img_data.append(img)
    img_label.append(training_set["label"][i])

# %%
img_data = np.array(img_data)
print(img_data.shape)
# Out:
# (12600, 150, 150, 3)

# %%
img_label = np.array(img_label)
print(img_label.shape)
# Out:
# (12600,)

# %%
# Define a function to randomly display training set images
# Code from https://www.kaggle.com/code/yohansandun/assignment-2-10?kernelSessionId=99056331

def display_random(n=1):
    plt.figure(figsize=(15, 20))
    for i in range(n):
        rnd = random.randint(0, len(training_set)-1)
        img_file = 'Human Action Recognition/train/' + training_set['filename'][rnd]

        if os.path.exists(img_file):
            plt.subplot(n//2+1, 2, i + 1)
            image = img.imread(img_file)
            plt.imshow(image)
            plt.title(training_set['label'][rnd])

# %%
display_random(10)
